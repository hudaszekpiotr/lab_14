# %% [markdown]
# # TEMAT 14 Test Driven Development(TDD)

# %% [markdown]
# ![sdsds.png](attachment:sdsds.png)

# %% [markdown]
# Najpierw stworzyłem repozytorium na githubie, oraz odpowiednią strukturę plików

# %%
Zdecydowałem się stworzyć i przetestować sortowanie bąbelkowe

# %% [markdown]
# ### Faza Red

# %% [markdown]
# ### Faza Green

# %% [markdown]
# ### Faza Refactor

# %% [markdown]
# ## Wnioski
